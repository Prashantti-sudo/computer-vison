# %%
# 📌 Step 1: Install YOLOv5 via Ultralytics (if not already installed)
# !pip install ultralytics --upgrade -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.0 MB/s eta 0:00:00

# %%
# 📌 Step 2: Upload an image
from google.colab import files
uploaded = files.upload()  # Select an image file (e.g., dog.jpg)

# Get the image path
image_path = list(uploaded.keys())[0]

# 📌 Step 3: Load the YOLOv5 model
from ultralytics import YOLO

# Load the pre-trained YOLOv5s model (you can use 'yolov8s' or others too)
model = YOLO("yolov5s.pt")  # Or "yolov8n.pt" for a smaller version

# 📌 Step 4: Run inference on the uploaded image
results = model(image_path)

# 📌 Step 5: Display the results using Matplotlib
from IPython.display import display, Image
import os

# Save output image
results[0].save(filename="result.jpg")  # Save annotated result

# Show it
import matplotlib.pyplot as plt
import cv2

img = cv2.imread("result.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 8))
plt.imshow(img)
plt.axis('off')
plt.title("YOLO Detection Output")
plt.show()

# 📌 Step 6: Optional - View detected objects and confidence
for r in results:
    for box in r.boxes:
        cls = int(box.cls[0])
        conf = float(box.conf[0])
        name = model.names[cls]
        print(f"Detected {name} with confidence {conf:.2f}")
# Out:
#      <input type="file" id="files-91c6ddbf-8d5d-46f6-a16c-1dc7fe740284" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-91c6ddbf-8d5d-46f6-a16c-1dc7fe740284">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
